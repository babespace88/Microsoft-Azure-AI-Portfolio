# %% [markdown]
# - The AI Insurance Agent is built to:
#
# Answer insurance questions clearly
#
# Provide fast and simple explanations
#
# Assist users with general insurance understanding
#
# Avoid unnecessary or unrelated responses
#
#
# - How It Works
#
# User asks an insurance-related question
#
# AI processes the query
#
# AI returns a short and direct answer
#
# If the question is not related to
# insurance, the AI will reject it politely

# %% [markdown]
# - Architecture
#
# Insurance claim Image/PDF
#
#         ↓
#
# Azure Content Understanding
#
#         ↓
#
# Structured JSON
#
#         ↓
#
# Fraud Detection Rules
#
#         ↓
#
# AI Agent Reasoning
#
#         ↓
#
# REAL / FAKE + Explanation

# %%
# !pip install azure-ai-projects>=2.1.0

# %%
! pip install azure-identity

# %%
# !curl -sL https://aka.ms/InstallAzureCLIDeb | sudo bash

# %%
# !az login

# %% [markdown]
# # DEPLOY AZURE AI INSURANCE CLAIM DETECTION AGENT

# %%
# =========================================
# INSTALL
# pip install azure-ai-projects>=2.1.0
# pip install azure-identity
# =========================================

from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

# =========================================
# AZURE AI FOUNDRY CONFIG
# =========================================

endpoint = "#"

project_client = AIProjectClient(
    endpoint=endpoint,
    credential=DefaultAzureCredential(),
)

# =========================================
# AGENT INFO
# =========================================

my_agent = "AI-Insurance-Agent"
my_version = "2"

# =========================================
# GET OPENAI CLIENT
# =========================================

openai_client = project_client.get_openai_client()

# =========================================
# AI PROMPT (TEXT ONLY)
# =========================================

prompt = """
macam mana saya nak buat saya keluar hospital dalam tempoh 24 jam? boleh ke saya claim insurance?
"""

# =========================================
# SEND REQUEST TO AGENT
# =========================================

response = openai_client.responses.create(
    model="gpt-4.1",

    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": prompt
                }
            ]
        }
    ],

    extra_body={
        "agent_reference": {
            "name": my_agent,
            "version": my_version,
            "type": "agent_reference"
        }
    }
)

# =========================================
# OUTPUT
# =========================================

print("\n========== AI AGENT INSURANCE ==========\n")
print(response.output_text)
# Out:
# ========== AI AGENT INSURANCE ==========
#
# Untuk keluar hospital dalam tempoh 24 jam, biasanya anda perlu mendapatkan kebenaran dan pengesahan doktor yang merawat. Sama ada anda boleh claim insurance atau tidak bergantung kepada polisi insurans anda—sesetengah polisi membenarkan claim untuk "daycare" atau rawatan kurang 24 jam, manakala sesetengah memerlukan minimum bermalam (admission at least 24 hours).
#
# Sila semak polisi insurans anda untuk pengesahan atau nyatakan jenis polisi anda untuk jawapan lebih tepat. Jika anda ingin saya semak dokumen polisi yang anda muat naik, sila beritahu nama polisi atau bahagian yang anda ingin tahu.

# %%
# =========================================
# INSTALL
# pip install azure-ai-projects>=2.1.0
# pip install azure-identity
# =========================================

from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient

# =========================================
# AZURE AI FOUNDRY CONFIG
# =========================================

endpoint = "#"

project_client = AIProjectClient(
    endpoint=endpoint,
    credential=DefaultAzureCredential(),
)

# =========================================
# AGENT INFO
# =========================================

my_agent = "AI-Insurance-Agent"
my_version = "2"

# =========================================
# GET OPENAI CLIENT
# =========================================

openai_client = project_client.get_openai_client()

# =========================================
# AI PROMPT (TEXT ONLY)
# =========================================

prompt = """
kalau saya bagi surat cuti sakit je untuk claim insurance boleh ke?
"""

# =========================================
# SEND REQUEST TO AGENT
# =========================================

response = openai_client.responses.create(
    model="gpt-4.1",

    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_text",
                    "text": prompt
                }
            ]
        }
    ],

    extra_body={
        "agent_reference": {
            "name": my_agent,
            "version": my_version,
            "type": "agent_reference"
        }
    }
)

# =========================================
# OUTPUT
# =========================================

print("\n========== AI AGENT INSURANCE ==========\n")
print(response.output_text)
# Out:
# ========== AI AGENT INSURANCE ==========
#
# Secara amnya, untuk claim insurance, surat cuti sakit sahaja mungkin tidak mencukupi. Biasanya, syarikat insurans perlukan dokumen sokongan lain seperti laporan perubatan (medical report) dan resit rawatan. Sila semak polisi insurans anda atau maklumat disyaratkan oleh syarikat insurans untuk memastikan dokumen yang diperlukan.
